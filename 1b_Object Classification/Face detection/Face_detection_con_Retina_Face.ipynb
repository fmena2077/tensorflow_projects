# %% [markdown]
# #Detección de rostros con Retina Face
#
# Implementar Retina Face es bastante simple, primero hay que instalar las dependencias

# %%
pip install retina-face
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for gdown: filename=gdown-3.14.0-py3-none-any.whl size=10055 sha256=50f97529b456bf4d926dac4dbdd83942f63663449318cc8dd93c83eae6ad5deb
#   Stored in directory: /root/.cache/pip/wheels/ee/cf/ac/e3ff09ceeea4bf7ff64b04de426caf3a8d0d1a299346ca54fd
# Successfully built gdown
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 3.6.4
#     Uninstalling gdown-3.6.4:
#       Successfully uninstalled gdown-3.6.4
# ...

# %%
import os
import urllib.request
urllib.request.urlretrieve('https://github.com/peteryuX/retinaface-tf2/blob/master/photo/0_Parade_marchingband_1_149.jpg?raw=true', 'marchingband.jpg')
# Out:
# ('marchingband.jpg', <http.client.HTTPMessage at 0x7f31d3763890>)

# %%
os.listdir()
# Out:
# ['.config', 'marchingband.jpg', 'sample_data']

# %%
from IPython.display import display
from PIL import Image
img_PIL = Image.open(r'marchingband.jpg')
display(img_PIL)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x684 at 0x7F31D33DED50>

# %%
from retinaface import RetinaFace
resp = RetinaFace.detect_faces("marchingband.jpg")
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created
# retinaface.h5 will be downloaded from the url https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# To: /root/.deepface/weights/retinaface.h5
# 100%|██████████| 119M/119M [00:01<00:00, 65.3MB/s]

# %%
#Toda la información que deseamos está presente
resp
# Out:
# {'face_1': {'facial_area': [371, 382, 399, 419],
#   'landmarks': {'left_eye': [390.10336, 395.32983],
#    'mouth_left': [388.3701, 408.5031],
#    'mouth_right': [377.41156, 408.5406],
#    'nose': [382.09387, 401.28506],
#    'right_eye': [377.00092, 395.37683]},
#   'score': 0.9803290367126465},
#  'face_10': {'facial_area': [570, 266, 591, 290],
#   'landmarks': {'left_eye': [582.85004, 274.58875],
#    'mouth_left': [581.87067, 284.44223],
#    'mouth_right': [576.5631, 284.29532],
#    'nose': [578.22894, 279.47952],
#    'right_eye': [575.6818, 274.22403]},
#   'score': 0.901917576789856},
#  'face_2': {'facial_area': [664, 237, 687, 267],
#   'landmarks': {'left_eye': [681.48016, 247.83487],
#    'mouth_left': [680.7641, 259.43192],
#    'mouth_right': [671.6802, 259.70087],
#    'nose': [676.1642, 253.22205],
#    'right_eye': [670.3197, 248.23567]},
#   'score': 0.9770092368125916},
#  'face_3': {'facial_area': [808, 241, 832, 270],
# ...

# %%
faces = RetinaFace.extract_faces(img_path = "marchingband.jpg", align = True)
for face in faces:
  plt.imshow(face)
  plt.show()

# %% [markdown]
# El modelo funcionó bastante bien! Aunque los cortes se ven un poco extraños. Si deseamos algo menos condenado por las llamas del infierno, probemos esta otra librería:

# %%
pip install deepface
# Out:
# ...
#      |████████████████████████████████| 61 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 20.1 MB/s
# ...

# %%
import os
import urllib.request
urllib.request.urlretrieve('https://i.blogs.es/5abcde/nicolas-cage-quiz/840_560.jpeg', 'nicolascage.jpeg')
# Out:
# ('nicolascage.jpeg', <http.client.HTTPMessage at 0x7f317fb23710>)

# %%
from IPython.display import display
from PIL import Image
img_PIL = Image.open(r'nicolascage.jpg')
display(img_PIL)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=840x560 at 0x7F317FA824D0>

# %%
from deepface import DeepFace
analysis = DeepFace.analyze(img_path = "nicolascage.jpeg", actions = ["age", "gender", "emotion", "race"], enforce_detection=False)
print(analysis)
# Out:
# Action: race: 100%|██████████| 4/4 [00:03<00:00,  1.23it/s]
# {'age': 38, 'region': {'x': 0, 'y': 0, 'w': 560, 'h': 840}, 'gender': 'Man', 'emotion': {'angry': 0.16521126963198185, 'disgust': 5.661564728143276e-05, 'fear': 9.902182221412659, 'happy': 0.919102132320404, 'sad': 71.76909446716309, 'surprise': 0.0017821006622398272, 'neutral': 17.242571711540222}, 'dominant_emotion': 'sad', 'race': {'asian': 30.52012026309967, 'indian': 7.328912615776062, 'black': 5.616342648863792, 'white': 24.61078315973282, 'middle eastern': 13.728521764278412, 'latino hispanic': 18.195322155952454}, 'dominant_race': 'asian'}

# %%
import os
import urllib.request
urllib.request.urlretrieve('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR73o1cA-NLDZkDj1HIE1F6GuvufPlTC4Jz8SijG5XmFWzUTifuz-8G1yhKVPASQEXDL4A&usqp=CAU', 'nicolascage2.jpeg')
# Out:
# ('nicolascage2.jpeg', <http.client.HTTPMessage at 0x7f317f8bb850>)

# %%
from IPython.display import display
from PIL import Image
img_PIL = Image.open(r'nicolascage2.jpeg')
display(img_PIL)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x275 at 0x7F317F8E94D0>

# %%
from deepface import DeepFace
analysis = DeepFace.analyze(img_path = "nicolascage2.jpeg", actions = ["age", "gender", "emotion", "race"])
print(analysis)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.95it/s]
# {'age': 31, 'region': {'x': 32, 'y': 55, 'w': 132, 'h': 132}, 'gender': 'Man', 'emotion': {'angry': 0.022739061387255788, 'disgust': 0.00014910561958458857, 'fear': 0.4607915412634611, 'happy': 82.38850235939026, 'sad': 0.46143708750605583, 'surprise': 0.03667993005365133, 'neutral': 16.62970334291458}, 'dominant_emotion': 'happy', 'race': {'asian': 2.8723785653710365, 'indian': 2.428875118494034, 'black': 0.4650447517633438, 'white': 54.95184659957886, 'middle eastern': 20.32610774040222, 'latino hispanic': 18.95574778318405}, 'dominant_race': 'white'}
